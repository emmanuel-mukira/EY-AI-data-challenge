# %% [markdown]
# # Water Quality Prediction: Benchmark Notebook

# %% [markdown]
# ## Challenge Overview

# %% [markdown]
# Welcome to the EY AI & Data Challenge 2026!
# The objective of this challenge is to build a robust **machine learning model** capable of predicting water quality across various river locations in South Africa. In addition to accurate predictions, the model should also identify and emphasize the key factors that significantly influence water quality.
#
# Participants will be provided with a dataset containing three water quality parameters — **Total Alkalinity**, **Electrical Conductance**, and **Dissolved Reactive Phosphorus** — collected between 2011 and 2015 from approximately 200 river locations across South Africa. Each data point includes the geographic coordinates (latitude and longitude) of the sampling site, the date of collection, and the corresponding water quality measurements.
#
# Using this dataset, participants are expected to build a machine learning model to predict water quality parameters for a separate validation dataset, which includes locations from different regions not present in the training data. The challenge also encourages participants to explore feature importance and provide insights into the factors most strongly associated with variations in water quality.
#
# This challenge is designed for participants with varying levels of experience in data science, remote sensing, and environmental analytics. It offers a valuable opportunity to apply machine learning techniques to real-world environmental data and contribute to advancing water quality monitoring using artificial intelligence.

# %% [markdown]
# **About the Notebook:**

# %% [markdown]
# In this notebook, we demonstrate a basic workflow that serves as a foundation for the challenge. The model has been developed to predict **water quality parameters** using features derived from the **Landsat** and **TerraClimate** datasets. Specifically, four spectral bands — **SWIR22** (Shortwave Infrared 2), **NIR** (Near Infrared), **Green**, and **SWIR16** (Shortwave Infrared 1) — were utilized from Landsat, along with derived spectral indices such as **NDMI** (Normalized Difference Moisture Index) and **MNDWI** (Modified Normalized Difference Water Index). In addition, the **PET** (Potential Evapotranspiration) variable was incorporated from the **TerraClimate** dataset to account for climatic influences on water quality.
#
# The dataset spans a five-year period from **2011 to 2015**. Using **API-based data extraction** methods, both Landsat and TerraClimate features were retrieved directly from the [Microsoft Planetary Computer portal](https://planetarycomputer.microsoft.com).
#
# These combined spectral, index-based, and climatic features were used as predictors in a regression model to estimate three key water quality parameters: **Total Alkalinity (TA)**, **Electrical Conductance (EC)**, and **Dissolved Reactive Phosphorus (DRP)**.
#
# Please note that this notebook serves only as a starting point. Several assumptions were made during the data extraction and model development process, which you may find opportunities to improve upon. Participants are encouraged to explore additional features, enhance preprocessing techniques, or experiment with different regression algorithms to optimize predictive performance.

# %% [markdown]
# ## Load In Dependencies
# The following code installs the required Python libraries (found in the requirements.txt file) in the Snowflake environment to allow successful execution of the remaining notebook code. After running this code for the first time, it is required to “restart” the kernal so the Python libraries are available in the environment. This is done by selecting the “Connected” menu above the notebook (next to “Run all”) and selecting the “restart kernal” link. Subsequent runs of the notebook do not require this “restart” process.

# %%
# Install requirements
# !pip install -r requirements.txt python-dotenv snowflake-connector-python snowflake-snowpark-python
# Out:
# Requirement already satisfied: python-dotenv in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: snowflake-connector-python in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (4.3.0)
# Requirement already satisfied: snowflake-snowpark-python in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (1.45.0)
# Requirement already satisfied: rioxarray==0.17.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied: pystac==1.11.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (1.11.0)
# Requirement already satisfied: pystac_client==0.9.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (0.9.0)
# Requirement already satisfied: planetary_computer==1.0.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: odc-stac==0.3.10 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (0.3.10)
# Requirement already satisfied: shapely==2.1.1 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (2.1.1)
# Requirement already satisfied: rasterio==1.4.3 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (1.4.3)
# Requirement already satisfied: tqdm==4.66.5 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (4.66.5)
# Requirement already satisfied: pandas==2.3.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (2.3.0)
# Requirement already satisfied: xarray==2025.3.1 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (2025.3.1)
# Requirement already satisfied: matplotlib==3.10.3 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (3.10.3)
# Requirement already satisfied: geopandas==1.1.1 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (1.1.1)
# Requirement already satisfied: seaborn==0.13.2 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (0.13.2)
# Requirement already satisfied: scikit-learn==1.5.2 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (1.5.2)
# Requirement already satisfied: netCDF4==1.7.2 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from -r requirements.txt (line 15)) (1.7.2)
# Requirement already satisfied: adlfs==2025.8.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from -r requirements.txt (line 16)) (2025.8.0)
# Requirement already satisfied: zarr==2.17.2 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from -r requirements.txt (line 17)) (2.17.2)
# Requirement already satisfied: dask==2024.10.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from -r requirements.txt (line 18)) (2024.10.0)
# Requirement already satisfied: numcodecs==0.12.1 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from -r requirements.txt (line 20)) (0.12.1)
# Requirement already satisfied: packaging in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from rioxarray==0.17.0->-r requirements.txt (line 1)) (26.0)
# Requirement already satisfied: pyproj>=3.3 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from rioxarray==0.17.0->-r requirements.txt (line 1)) (3.7.2)
# Requirement already satisfied: numpy>=1.23 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from rioxarray==0.17.0->-r requirements.txt (line 1)) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.7.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from pystac==1.11.0->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: requests>=2.28.2 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from pystac_client==0.9.0->-r requirements.txt (line 3)) (2.32.5)
# Requirement already satisfied: click>=7.1 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from planetary_computer==1.0.0->-r requirements.txt (line 4)) (8.3.1)
# Requirement already satisfied: pydantic>=1.7.3 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from planetary_computer==1.0.0->-r requirements.txt (line 4)) (2.12.5)
# Requirement already satisfied: pytz>=2020.5 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from planetary_computer==1.0.0->-r requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: affine in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from odc-stac==0.3.10->-r requirements.txt (line 5)) (2.4.0)
# Requirement already satisfied: odc-geo>=0.4.7 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from odc-stac==0.3.10->-r requirements.txt (line 5)) (0.5.0)
# Requirement already satisfied: toolz in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from odc-stac==0.3.10->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: attrs in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from rasterio==1.4.3->-r requirements.txt (line 7)) (25.4.0)
# Requirement already satisfied: certifi in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from rasterio==1.4.3->-r requirements.txt (line 7)) (2026.1.4)
# Requirement already satisfied: cligj>=0.5 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from rasterio==1.4.3->-r requirements.txt (line 7)) (0.7.2)
# Requirement already satisfied: click-plugins in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from rasterio==1.4.3->-r requirements.txt (line 7)) (1.1.1.2)
# Requirement already satisfied: pyparsing in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from rasterio==1.4.3->-r requirements.txt (line 7)) (3.3.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from pandas==2.3.0->-r requirements.txt (line 9)) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from matplotlib==3.10.3->-r requirements.txt (line 11)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from matplotlib==3.10.3->-r requirements.txt (line 11)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from matplotlib==3.10.3->-r requirements.txt (line 11)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from matplotlib==3.10.3->-r requirements.txt (line 11)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from matplotlib==3.10.3->-r requirements.txt (line 11)) (12.1.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from geopandas==1.1.1->-r requirements.txt (line 12)) (0.12.1)
# Requirement already satisfied: scipy>=1.6.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from scikit-learn==1.5.2->-r requirements.txt (line 14)) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from scikit-learn==1.5.2->-r requirements.txt (line 14)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from scikit-learn==1.5.2->-r requirements.txt (line 14)) (3.6.0)
# Requirement already satisfied: cftime in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from netCDF4==1.7.2->-r requirements.txt (line 15)) (1.6.5)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from adlfs==2025.8.0->-r requirements.txt (line 16)) (1.38.1)
# Requirement already satisfied: azure-datalake-store<0.1,>=0.0.53 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from adlfs==2025.8.0->-r requirements.txt (line 16)) (0.0.53)
# Requirement already satisfied: azure-identity in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from adlfs==2025.8.0->-r requirements.txt (line 16)) (1.25.2)
# Requirement already satisfied: azure-storage-blob>=12.17.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from adlfs==2025.8.0->-r requirements.txt (line 16)) (12.28.0)
# Requirement already satisfied: fsspec>=2023.12.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from adlfs==2025.8.0->-r requirements.txt (line 16)) (2026.2.0)
# Requirement already satisfied: aiohttp>=3.7.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from adlfs==2025.8.0->-r requirements.txt (line 16)) (3.13.3)
# Requirement already satisfied: asciitree in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from zarr==2.17.2->-r requirements.txt (line 17)) (0.3.3)
# Requirement already satisfied: fasteners in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from zarr==2.17.2->-r requirements.txt (line 17)) (0.20)
# Requirement already satisfied: cloudpickle>=3.0.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from dask==2024.10.0->-r requirements.txt (line 18)) (3.1.1)
# Requirement already satisfied: partd>=1.4.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from dask==2024.10.0->-r requirements.txt (line 18)) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from dask==2024.10.0->-r requirements.txt (line 18)) (6.0.3)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from snowflake-connector-python) (1.5.1)
# Requirement already satisfied: cryptography>=44.0.1 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from snowflake-connector-python) (46.0.5)
# Requirement already satisfied: pyOpenSSL<26.0.0,>=24.0.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from snowflake-connector-python) (25.3.0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from snowflake-connector-python) (2.11.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from snowflake-connector-python) (3.4.4)
# Requirement already satisfied: idna<4,>=3.7 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from snowflake-connector-python) (3.11)
# Requirement already satisfied: typing_extensions<5,>=4.3 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from snowflake-connector-python) (4.15.0)
# Requirement already satisfied: filelock<4,>=3.5 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from snowflake-connector-python) (3.24.2)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from snowflake-connector-python) (4.9.2)
# Requirement already satisfied: tomlkit in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from snowflake-connector-python) (0.14.0)
# Requirement already satisfied: boto3>=1.24 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from snowflake-connector-python) (1.42.51)
# Requirement already satisfied: botocore>=1.24 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from snowflake-connector-python) (1.42.51)
# Requirement already satisfied: setuptools>=40.6.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from snowflake-snowpark-python) (82.0.0)
# Requirement already satisfied: wheel in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from snowflake-snowpark-python) (0.46.3)
# Requirement already satisfied: protobuf<6.34,>=3.20 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from snowflake-snowpark-python) (6.33.5)
# Requirement already satisfied: tzlocal in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from snowflake-snowpark-python) (5.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from aiohttp>=3.7.0->adlfs==2025.8.0->-r requirements.txt (line 16)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from aiohttp>=3.7.0->adlfs==2025.8.0->-r requirements.txt (line 16)) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from aiohttp>=3.7.0->adlfs==2025.8.0->-r requirements.txt (line 16)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from aiohttp>=3.7.0->adlfs==2025.8.0->-r requirements.txt (line 16)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from aiohttp>=3.7.0->adlfs==2025.8.0->-r requirements.txt (line 16)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from aiohttp>=3.7.0->adlfs==2025.8.0->-r requirements.txt (line 16)) (1.22.0)
# Requirement already satisfied: cffi in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from azure-datalake-store<0.1,>=0.0.53->adlfs==2025.8.0->-r requirements.txt (line 16)) (2.0.0)
# Requirement already satisfied: msal<2,>=1.16.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from azure-datalake-store<0.1,>=0.0.53->adlfs==2025.8.0->-r requirements.txt (line 16)) (1.34.0)
# Requirement already satisfied: isodate>=0.6.1 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from azure-storage-blob>=12.17.0->adlfs==2025.8.0->-r requirements.txt (line 16)) (0.7.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from boto3>=1.24->snowflake-connector-python) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from boto3>=1.24->snowflake-connector-python) (0.16.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from botocore>=1.24->snowflake-connector-python) (2.6.3)
# Requirement already satisfied: cachetools in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from odc-geo>=0.4.7->odc-stac==0.3.10->-r requirements.txt (line 5)) (7.0.1)
# Requirement already satisfied: locket in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from partd>=1.4.0->dask==2024.10.0->-r requirements.txt (line 18)) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from pydantic>=1.7.3->planetary_computer==1.0.0->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from pydantic>=1.7.3->planetary_computer==1.0.0->-r requirements.txt (line 4)) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from pydantic>=1.7.3->planetary_computer==1.0.0->-r requirements.txt (line 4)) (0.4.2)
# Requirement already satisfied: jsonschema~=4.18 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from pystac[validation]>=1.10.0->pystac_client==0.9.0->-r requirements.txt (line 3)) (4.26.0)
# Requirement already satisfied: six>=1.5 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from python-dateutil>=2.7.0->pystac==1.11.0->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from azure-identity->adlfs==2025.8.0->-r requirements.txt (line 16)) (1.3.1)
# Requirement already satisfied: bottleneck in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from xarray==2025.3.1->-r requirements.txt (line 10)) (1.6.0)
# Requirement already satisfied: numbagg in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from xarray==2025.3.1->-r requirements.txt (line 10)) (0.9.4)
# Requirement already satisfied: numba>=0.54 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from xarray==2025.3.1->-r requirements.txt (line 10)) (0.63.1)
# Requirement already satisfied: flox in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from xarray==2025.3.1->-r requirements.txt (line 10)) (0.11.1)
# Requirement already satisfied: opt_einsum in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from xarray==2025.3.1->-r requirements.txt (line 10)) (3.4.0)
# Requirement already satisfied: h5netcdf in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from xarray==2025.3.1->-r requirements.txt (line 10)) (1.8.1)
# Requirement already satisfied: pooch in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from xarray==2025.3.1->-r requirements.txt (line 10)) (1.9.0)
# Requirement already satisfied: sparse in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from xarray==2025.3.1->-r requirements.txt (line 10)) (0.17.0)
# Requirement already satisfied: cartopy in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from xarray==2025.3.1->-r requirements.txt (line 10)) (0.25.0)
# Requirement already satisfied: nc-time-axis in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from xarray==2025.3.1->-r requirements.txt (line 10)) (1.4.1)
# Requirement already satisfied: pycparser in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from cffi->azure-datalake-store<0.1,>=0.0.53->adlfs==2025.8.0->-r requirements.txt (line 16)) (3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client==0.9.0->-r requirements.txt (line 3)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client==0.9.0->-r requirements.txt (line 3)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac_client==0.9.0->-r requirements.txt (line 3)) (0.30.0)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from numba>=0.54->xarray==2025.3.1->-r requirements.txt (line 10)) (0.46.0)
# Requirement already satisfied: pyshp>=2.3 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from cartopy->xarray==2025.3.1->-r requirements.txt (line 10)) (3.0.3)
# Requirement already satisfied: pyarrow>=14.0.1 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from dask==2024.10.0->-r requirements.txt (line 18)) (23.0.1)
# Requirement already satisfied: lz4>=4.3.2 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from dask==2024.10.0->-r requirements.txt (line 18)) (4.4.5)
# Requirement already satisfied: numpy_groupies>=0.9.19 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from flox->xarray==2025.3.1->-r requirements.txt (line 10)) (0.11.3)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from dask==2024.10.0->-r requirements.txt (line 18)) (1.1.16)
# Requirement already satisfied: bokeh>=3.1.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from dask==2024.10.0->-r requirements.txt (line 18)) (3.8.2)
# Requirement already satisfied: jinja2>=2.10.3 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from dask==2024.10.0->-r requirements.txt (line 18)) (3.1.6)
# Requirement already satisfied: distributed==2024.10.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from dask==2024.10.0->-r requirements.txt (line 18)) (2024.10.0)
# Requirement already satisfied: msgpack>=1.0.2 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from distributed==2024.10.0->dask==2024.10.0->-r requirements.txt (line 18)) (1.1.2)
# Requirement already satisfied: psutil>=5.8.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from distributed==2024.10.0->dask==2024.10.0->-r requirements.txt (line 18)) (7.2.2)
# Requirement already satisfied: tblib>=1.6.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from distributed==2024.10.0->dask==2024.10.0->-r requirements.txt (line 18)) (3.2.2)
# Requirement already satisfied: tornado>=6.2.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from distributed==2024.10.0->dask==2024.10.0->-r requirements.txt (line 18)) (6.5.4)
# Requirement already satisfied: zict>=3.0.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from distributed==2024.10.0->dask==2024.10.0->-r requirements.txt (line 18)) (3.0.0)
# Requirement already satisfied: narwhals>=1.13 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from bokeh>=3.1.0->dask==2024.10.0->-r requirements.txt (line 18)) (2.16.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from bokeh>=3.1.0->dask==2024.10.0->-r requirements.txt (line 18)) (2025.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/emmanuel/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages (from jinja2>=2.10.3->dask==2024.10.0->-r requirements.txt (line 18)) (3.0.3)

# %%
# Setup environment
import os
from dotenv import load_dotenv
from snowflake.snowpark import Session

session = Session.builder.configs({
    "account": "jfecknb-lwb72940",
    "user": "EmmanuelMukira",  # Fixed: Correct username without space
    "password": "qikcox-kifxe4-xodqIn",  # Fixed: Removed trailing space
    "warehouse": "COMPUTE_WH",
    "database": "USER$EMMANUELMUKIRA",
    "schema": "PUBLIC"
}).create()

print("🚀 Ready to run benchmark model!")
print("📁 Current directory:", os.getcwd())
print("📋 Available files:", os.listdir()[:5])  # Show first 5 files
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[7], line 14
#       3 from dotenv import load_dotenv
#       4 from snowflake.snowpark import Session
#       7 session = Session.builder.configs({
#       8     "account": "jfecknb-lwb72940",
#       9     "user": "EMMANUELMUKIRA",
#      10     "password": "qikcox-kifxe4-xodqIn ",
#      11     "warehouse": "COMPUTE_WH",
#      12     "database": "USER$EMMANUELMUKIRA",
#      13     "schema": "PUBLIC"
# ---> 14 }).create()
#      16 print("🚀 Ready to run benchmark model!")
#      17 print("📁 Current directory:", os.getcwd())
#
# File ~/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages/snowflake/snowpark/session.py:526, in Session.SessionBuilder.create(self)
#     524     _add_session(session)
#     525 else:
# --> 526     session = self._create_internal(self._options.get("connection"))
#     528 if self._app_name:
#     529     if self._format_json:
#
# File ~/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages/snowflake/snowpark/session.py:568, in Session.SessionBuilder._create_internal(self, conn)
#     565 if "paramstyle" not in self._options:
#     566     self._options["paramstyle"] = "qmark"
#     567 new_session = Session(
# --> 568     ServerConnection({}, conn) if conn else ServerConnection(self._options),
#     569     self._options,
#     570 )
#     572 if "password" in self._options:
#     573     self._options["password"] = None
#
# File ~/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages/snowflake/snowpark/_internal/server_connection.py:169, in ServerConnection.__init__(self, options, conn)
#     167 self._lower_case_parameters = {k.lower(): v for k, v in options.items()}
#     168 self._add_application_parameters()
# --> 169 self._conn = conn if conn else connect(**self._lower_case_parameters)
#     170 self.max_string_size = DEFAULT_STRING_SIZE
#     171 if self._conn._session_parameters:
#
# File ~/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages/snowflake/connector/__init__.py:64, in Connect(**kwargs)
#      62 @wraps(SnowflakeConnection.__init__)
#      63 def Connect(**kwargs) -> SnowflakeConnection:
# ---> 64     return SnowflakeConnection(**kwargs)
#
# File ~/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages/snowflake/connector/connection.py:681, in SnowflakeConnection.__init__(self, connection_name, connections_file_path, **kwargs)
#     679     kwargs = _get_default_connection_params()
#     680 self.__set_error_attributes()
# --> 681 self.connect(**kwargs)
#     682 self._telemetry = TelemetryClient(self._rest)
#     683 self.expired = False
#
# File ~/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages/snowflake/connector/connection.py:1177, in SnowflakeConnection.connect(self, **kwargs)
#    1175             raise Exception(str(exceptions_dict))
#    1176 else:
# -> 1177     self.__open_connection()
#    1179 # Register the connection in the pool after successful connection
#    1180 _connections_registry.add_connection(self)
#
# File ~/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages/snowflake/connector/connection.py:1616, in SnowflakeConnection.__open_connection(self)
#    1608 else:
#    1609     # okta URL, e.g., https://<account>.okta.com/
#    1610     self.auth_class = AuthByOkta(
#    1611         application=self.application,
#    1612         timeout=self.login_timeout,
#    1613         backoff_generator=self._backoff_generator,
#    1614     )
# -> 1616 self.authenticate_with_retry(self.auth_class)
#    1618 self._password = None  # ensure password won't persist
#    1619 self.auth_class.reset_secrets()
#
# File ~/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages/snowflake/connector/connection.py:1952, in SnowflakeConnection.authenticate_with_retry(self, auth_instance)
#    1949 def authenticate_with_retry(self, auth_instance) -> None:
#    1950     # make some changes if needed before real __authenticate
#    1951     try:
# -> 1952         self._authenticate(auth_instance)
#    1953     except ReauthenticationRequest as ex:
#    1954         # cached id_token expiration error, we have cleaned id_token and try to authenticate again
#    1955         logger.debug("ID token expired. Reauthenticating...: %s", ex)
#
# File ~/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages/snowflake/connector/connection.py:1984, in SnowflakeConnection._authenticate(self, auth_instance)
#    1982 auth_instance._retry_ctx.set_start_time()
#    1983 try:
# -> 1984     auth.authenticate(
#    1985         auth_instance=auth_instance,
#    1986         account=self.account,
#    1987         user=self.user,
#    1988         database=self.database,
#    1989         schema=self.schema,
#    1990         warehouse=self.warehouse,
#    1991         role=self.role,
#    1992         passcode=self._passcode,
#    1993         passcode_in_password=self._passcode_in_password,
#    1994         mfa_callback=self._mfa_callback,
#    1995         password_callback=self._password_callback,
#    1996         session_parameters=self._session_parameters,
#    1997     )
#    1998 except OperationalError as e:
#    1999     logger.debug(
#    2000         "Operational Error raised at authentication"
#    2001         f"for authenticator: {type(auth_instance).__name__}"
#    2002     )
#
# File ~/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages/snowflake/connector/auth/_auth.py:444, in Auth.authenticate(self, auth_instance, account, user, database, schema, warehouse, role, passcode, passcode_in_password, mfa_callback, password_callback, session_parameters, timeout)
#     440     if isinstance(auth_instance, AuthByUsrPwdMfa):
#     441         self._delete_temporary_credential(
#     442             self._rest._host, user, TokenType.MFA_TOKEN
#     443         )
# --> 444     Error.errorhandler_wrapper(
#     445         self._rest._connection,
#     446         None,
#     447         DatabaseError,
#     448         {
#     449             "msg": (
#     450                 "Failed to connect to DB: {host}:{port}. " "{message}"
#     451             ).format(
#     452                 host=self._rest._host,
#     453                 port=self._rest._port,
#     454                 message=ret["message"],
#     455             ),
#     456             "errno": ER_FAILED_TO_CONNECT_TO_DB,
#     457             "sqlstate": SQLSTATE_CONNECTION_WAS_NOT_ESTABLISHED,
#     458         },
#     459     )
#     460 else:
#     461     logger.debug(
#     462         "token = %s",
#     463         (
#    (...)    467         ),
#     468     )
#
# File ~/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages/snowflake/connector/errors.py:298, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     275 @staticmethod
#     276 def errorhandler_wrapper(
#     277     connection: SnowflakeConnection | None,
#    (...)    280     error_value: dict[str, Any],
#     281 ) -> None:
#     282     """Error handler wrapper that calls the errorhandler method.
#     283
#     284     Args:
#    (...)    295         exception to the first handler in that order.
#     296     """
# --> 298     handed_over = Error.hand_to_other_handler(
#     299         connection,
#     300         cursor,
#     301         error_class,
#     302         error_value,
#     303     )
#     304     if not handed_over:
#     305         raise Error.errorhandler_make_exception(
#     306             error_class,
#     307             error_value,
#     308         )
#
# File ~/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages/snowflake/connector/errors.py:361, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     359 elif connection is not None:
#     360     try:
# --> 361         connection.errorhandler(connection, cursor, error_class, error_value)
#     362     except NotImplementedError:
#     363         # for async compatibility, check SNOW-1763096 and SNOW-1763103
#     364         connection._errorhandler(connection, cursor, error_class, error_value)
#
# File ~/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages/snowflake/connector/errors.py:229, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     227 errno = error_value.get("errno")
#     228 done_format_msg = error_value.get("done_format_msg")
# --> 229 raise error_class(
#     230     msg=error_value.get("msg"),
#     231     errno=None if errno is None else int(errno),
#     232     sqlstate=error_value.get("sqlstate"),
#     233     sfqid=error_value.get("sfqid"),
#     234     query=error_value.get("query"),
#     235     done_format_msg=(
#     236         None if done_format_msg is None else bool(done_format_msg)
#     237     ),
#     238     connection=connection,
#     239     cursor=cursor,
#     240 )
#
# DatabaseError: 250001 (08001): Failed to connect to DB: jfecknb-lwb72940.snowflakecomputing.com:443. Incorrect username or password was specified.

# %%
# Session already created in Cell 1 - use that variable
# Skip get_active_session() - it only works in Snowflake notebooks

# Suppress warnings
import warnings
warnings.filterwarnings('ignore')

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Data manipulation and analysis
import numpy as np
import pandas as pd
from IPython.display import display

# Multi-dimensional arrays and datasets (e.g., NetCDF, Zarr)
import xarray as xr

# Geospatial raster data handling with CRS support
import rioxarray as rxr

# Raster operations and spatial windowing
import rasterio
from rasterio.windows import Window

# Feature preprocessing and data splitting
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from scipy.spatial import cKDTree

# Machine Learning
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# Planetary Computer tools for STAC API access and authentication
import pystac_client
import planetary_computer as pc
from odc.stac import stac_load
from pystac.extensions.eo import EOExtension as eo

from datetime import date
from tqdm import tqdm
import os
# Out:
# ---------------------------------------------------------------------------
# SnowparkSessionException                  Traceback (most recent call last)
# Cell In[2], line 3
#       1 import snowflake
#       2 from snowflake.snowpark.context import get_active_session
# ----> 3 session = get_active_session()
#       5 # Suppress warnings
#       6 import warnings
#
# File ~/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages/snowflake/snowpark/context.py:113, in get_active_session()
#     105 def get_active_session() -> "snowflake.snowpark.Session":
#     106     """Returns the current active Snowpark session.
#     107
#     108     Raises: SnowparkSessionException: If there is more than one active session or no active sessions.
#    (...)    111         A :class:`Session` object for the current session.
#     112     """
# --> 113     return snowflake.snowpark.session._get_active_session()
#
# File ~/EY-AI-data-challenge/ey-challenge-env/lib/python3.12/site-packages/snowflake/snowpark/session.py:332, in _get_active_session()
#     330     raise SnowparkClientExceptionMessages.MORE_THAN_ONE_ACTIVE_SESSIONS()
#     331 else:
# --> 332     raise SnowparkClientExceptionMessages.SERVER_NO_DEFAULT_SESSION()
#
# SnowparkSessionException: (1403): No default Session is found. Please create a session before you call function 'udf' or use decorator '@udf'.

# %% [markdown]
# ## Response Variable

# %% [markdown]
# Before building the model, we first load the **water quality training dataset**. The curated dataset contains samples collected from various monitoring stations across the study region. Each record includes the geographical coordinates (Latitude and Longitude), the sample collection date, and the corresponding **measured values** for the three key water quality parameters — **Total Alkalinity (TA)**, **Electrical Conductance (EC)**, and **Dissolved Reactive Phosphorus (DRP)**.

# %%
Water_Quality_df = pd.read_csv("water_quality_training_dataset.csv")
display(Water_Quality_df.head(5))

# %% [markdown]
# ## Predictor Variables

# %% [markdown]
# Now that we have our water quality dataset, the next step is to gather the predictor variables from the **Landsat** and **TerraClimate** datasets. In this notebook, we demonstrate how to **load previously extracted satellite and climate data** from separate files, rather than performing the extraction directly, which allows for a smoother and faster experience. Participants can refer to the dedicated extraction notebooks—one for Landsat and another for TerraClimate—to understand how the data was retrieved and processed, and they can also generate their own output CSV files if needed. Using these pre-extracted CSV files, this notebook focuses on loading the predictor features and running the subsequent analysis and model training efficiently.
#
# For more detailed guidance on the original data extraction process, you can review the Landsat and TerraClimate example notebooks available on the Planetary Computer portal:
#
# - [Landsat-c2-l2 - Example-Notebook](https://planetarycomputer.microsoft.com/dataset/landsat-c2-l2#Example-Notebook)
# - [Terraclimate - Example-Notebook](https://planetarycomputer.microsoft.com/dataset/terraclimate#Example-Notebook)
#
# We have used selected spectral bands — **SWIR22** (Shortwave Infrared 2), **NIR** (Near Infrared), **Green**, and **SWIR16** (Shortwave Infrared 1) — and computed key spectral indices such as **NDMI** (Normalized Difference Moisture Index) and **MNDWI** (Modified Normalized Difference Water Index). These features capture surface moisture, vegetation, and water content characteristics that influence water quality variability.
#
# In addition to Landsat features, we also incorporated the **Potential Evapotranspiration (PET)** variable from the **TerraClimate** dataset, which provides high-resolution global climate data. The PET feature captures the atmospheric demand for moisture, representing climatic conditions such as temperature, humidity, and radiation that influence surface water evaporation and thus affect water quality parameters.
#
# The predictor features include:
#
# - **SWIR22** – Sensitive to surface moisture and turbidity variations in water bodies.
# - **NIR** – Helps in identifying vegetation and suspended matter in water.
# - **Green** – Useful for detecting water color and surface reflectance changes.
# - **SWIR16** – Provides information on surface dryness and sediment concentration.
# - **NDMI** – Derived from NIR and SWIR16, indicates moisture and vegetation–water interaction.
# - **MNDWI** – Derived from Green and SWIR22, effective for distinguishing open water areas and reducing built-up noise.
# - **PET** – Extracted from the TerraClimate dataset, represents potential evapotranspiration influencing hydrological and water quality dynamics.

# %% [markdown]
# ### **Tip 1**
#
# Participants are encouraged to experiment with different combinations of **Landsat** bands or even include data from other public satellite data sources. By creating mathematical combinations of bands, you can derive various spectral indices that capture surface and environmental characteristics.

# %% [markdown]
# ### Loading Pre-Extracted Landsat Data
#
# In this notebook, we **load previously extracted Landsat data** from CSV files generated in a separate extraction notebook. This approach ensures a smoother and faster workflow, allowing participants to focus on data analysis and model development without waiting for time-consuming data retrieval.
#
# Participants are expected to generate their own data extraction CSV files by running the dedicated Landsat extraction notebook. These CSV files can then be used here to smoothly run this benchmark notebook. Participants can refer to the extraction notebook to understand the API-based process, including how individual bands and indices like **NDMI** were computed. Using these pre-extracted CSV files simplifies preprocessing and is ideal for large-scale environmental and water quality analysis.

# %% [markdown]
# ### **Tip 2**
#
# In the data extraction process (performed in the dedicated extraction notebooks), a 100 m focal buffer was applied around each sampling location rather than using a single point. Participants may explore creating different focal buffers around the locations (e.g., 50 m, 150 m, etc.) during extraction. For example, if a 50 m buffer was used for “Band 2”, the extracted CSV values would reflect the average of Band 2 within 50 meters of each location. This approach can help reduce errors associated with spatial autocorrelation.

# %%
landsat_train_features = pd.read_csv("landsat_features_training.csv")
display(landsat_train_features.head(5))

# %%
# If NDMI and MNDWI columns are of type object, convert them to float
landsat_train_features['NDMI'] = landsat_train_features['NDMI'].astype(float)
landsat_train_features['MNDWI'] = landsat_train_features['MNDWI'].astype(float)

# %% [markdown]
# ### Loading Pre-Extracted TerraClimate Data
#
# In this notebook, we **load previously extracted TerraClimate data** from CSV files generated in a dedicated extraction notebook. This approach ensures a smoother and faster workflow, allowing participants to focus on data analysis and model development without waiting for time-consuming data retrieval.
#
# Participants are expected to generate their own data extraction CSV files by running the dedicated TerraClimate extraction notebook. These CSV files can then be used here to smoothly run this benchmark notebook. Participants can refer to the extraction notebook to understand the API-based process, including how climate variables such as **Potential Evapotranspiration (PET)** were extracted. Using these pre-extracted CSV files ensures consistent, automated retrieval of high-resolution climate data that can be easily integrated with satellite-derived features for comprehensive environmental and hydrological analysis.

# %%
Terraclimate_df = pd.read_csv("terraclimate_features_training.csv")
display(Terraclimate_df.head(5))

# %% [markdown]
# ## Joining the Predictor Variables and Response Variables
#
# Now that we have extracted our predictor variables, we need to join them with the response variables. We use the **combine_two_datasets** function to merge the predictor variables and response variables. The **concat** function from pandas is particularly useful for this step.

# %%
# Combine two datasets vertically (along columns) using pandas concat function.
def combine_two_datasets(dataset1,dataset2,dataset3):
    '''
    Returns a  vertically concatenated dataset.
    Attributes:
    dataset1 - Dataset 1 to be combined 
    dataset2 - Dataset 2 to be combined
    '''
    
    data = pd.concat([dataset1,dataset2,dataset3], axis=1)
    data = data.loc[:, ~data.columns.duplicated()]
    return data

# %%
# Combining ground data and final data into a single dataset.
wq_data = combine_two_datasets(Water_Quality_df, landsat_train_features, Terraclimate_df)
display(wq_data.head(5))

# %% [markdown]
# ### Handling Missing Values
#
# Before model training, missing values in the dataset were carefully handled to ensure data consistency and prevent model bias. Numerical columns were imputed using their median values, maintaining the overall data distribution while minimizing the impact of outliers.

# %%
wq_data = wq_data.fillna(wq_data.median(numeric_only=True))
wq_data.isna().sum()

# %% [markdown]
# ## Model Building

# %% [markdown]
# Now let us select the columns required for our model-building exercise. We will consider only **SWIR22**, **NDMI**, and **MNDWI** from the Landsat data, and **PET** from the TerraClimate dataset as our predictor variables. It does not make sense to use latitude and longitude as predictor variables, as they do not have any direct impact on predicting the water quality parameters.

# %%
# Retaining only the columns for swir22, NDMI, MNDWI, pet, Total Alkalinity, Electrical Conductance and Dissolved Reactive Phosphorus Index in the dataset.
wq_data = wq_data[['swir22','NDMI','MNDWI','pet', 'Total Alkalinity', 'Electrical Conductance', 'Dissolved Reactive Phosphorus']]

# %% [markdown]
# ### **Tip 3**
#
# We are developing individual models for each water quality parameter using a common set of features: **SWIR22**, **NDMI**, **MNDWI**, and **PET**. However, participants are encouraged to experiment with different feature combinations to build more robust machine learning models.

# %% [markdown]
# ## Helper Functions
#
# ### Train and Test Split
# We will now split the data into 70% training data and 30% test data. Scikit-learn (sklearn) is a robust library for machine learning in Python. The `model_selection` module in scikit-learn provides the `train_test_split` function, which can be used for this purpose.
#
# ### Feature Scaling
# Before initiating model training, we may need to perform various data preprocessing steps. Here, we demonstrate scaling of the variables **SWIR22**, **NDMI**, **MNDWI**, and **PET** using StandardScaler.
#
# Feature scaling is an essential preprocessing step for numerical features. Many machine learning algorithms—such as gradient descent methods, KNN, and linear or logistic regression—require scaling to achieve optimal performance. Scikit-learn provides several scaling utilities. In this notebook, we use **StandardScaler**, which transforms the data so that each feature has a mean of 0 and a standard deviation of 1.
#
# ### Model Training
# Now that we have the data in a format suitable for machine learning, we can begin training our models. In this demonstration notebook, we build three separate regression models—one for each target water quality parameter: **Total Alkalinity**, **Electrical Conductance**, and **Dissolved Reactive Phosphorus**. Each model is trained independently to capture the unique relationships between the satellite-derived features and each water quality parameter.
#
# We use the **Random Forest Regressor** from the scikit-learn library for model training. Scikit-learn offers a wide range of regression algorithms, along with powerful parameter tuning and customization options.
#
# For model training, the predictor variables (e.g., SWIR22, NDMI, MNDWI, and PET) are stored in an array `X`, and the response variable (one of the water quality parameters) is stored in an array `Y`. Note that the response variable should not be included in `X`. Also, latitude, longitude, and sample date are excluded from the predictor variables since they serve only as spatial and temporal references.
#
# ### Model Evaluation
# After training the models for the three water quality parameters, the next step is to evaluate their performance. Each regression model—Total Alkalinity, Electrical Conductance, and Dissolved Reactive Phosphorus—is assessed using:
#
# - **R² Score**: Measures how well the model explains the variance in the observed values.
# - **RMSE (Root Mean Square Error)**: Quantifies the average magnitude of prediction errors.
#
# Together, these metrics help determine how effectively each model captures variations in water quality across locations and sampling dates. Scikit-learn provides built-in functions to compute both metrics. Participants may also explore additional evaluation techniques or custom metrics to enhance model assessment.

# %% [markdown]
# ### **Tip 4**
#
# There are many data preprocessing methods available that may help improve model performance. Participants are encouraged to explore various preprocessing techniques as well as different machine learning algorithms to build a more robust model.

# %%
def split_data(X, y, test_size=0.3, random_state=42):
    return train_test_split(X, y, test_size=test_size, random_state=random_state)

def scale_data(X_train, X_test):
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    return X_train_scaled, X_test_scaled, scaler

def train_model(X_train_scaled, y_train):
    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train_scaled, y_train)
    return model

def evaluate_model(model, X_scaled, y_true, dataset_name="Test"):
    y_pred = model.predict(X_scaled)
    r2 = r2_score(y_true, y_pred)
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    print(f"\n{dataset_name} Evaluation:")
    print(f"R²: {r2:.3f}")
    print(f"RMSE: {rmse:.3f}")
    return y_pred, r2, rmse

# %% [markdown]
# ## Model Workflow (Pipeline)
#
# The complete model development process follows a structured pipeline to ensure consistency, reproducibility, and clarity. Each stage in the workflow is modularized into independent functions that can be reused for different water quality parameters. This modular approach streamlines the process and makes the workflow easily adaptable to new datasets or parameters in the future.
#
# The pipeline automates the sequence of steps — from data preparation to evaluation — for each target parameter. The same set of predictor variables is used, while the response variable changes for each of the three targets: *Total Alkalinity (TA)*, *Electrical Conductance (EC)*, and *Dissolved Reactive Phosphorus (DRP)*. By maintaining a consistent framework, comparisons across models remain fair and interpretable.

# %%
def run_pipeline(X, y, param_name="Parameter"):
    print(f"\n{'='*60}")
    print(f"Training Model for {param_name}")
    print(f"{'='*60}")
    
    # Split data
    X_train, X_test, y_train, y_test = split_data(X, y)
    
    # Scale
    X_train_scaled, X_test_scaled, scaler = scale_data(X_train, X_test)
    
    # Train
    model = train_model(X_train_scaled, y_train)
    
    # Evaluate (in-sample)
    y_train_pred, r2_train, rmse_train = evaluate_model(model, X_train_scaled, y_train, "Train")
    
    # Evaluate (out-sample)
    y_test_pred, r2_test, rmse_test = evaluate_model(model, X_test_scaled, y_test, "Test")
    
    # Return summary
    results = {
        "Parameter": param_name,
        "R2_Train": r2_train,
        "RMSE_Train": rmse_train,
        "R2_Test": r2_test,
        "RMSE_Test": rmse_test
    }
    return model, scaler, pd.DataFrame([results])

# %% [markdown]
# ### Model Training and Evaluation for Each Parameter

# %% [markdown]
# In this step, we apply the complete modeling pipeline to each of the three selected water quality parameters — Total Alkalinity, Electrical Conductance, and Dissolved Reactive Phosphorus. The input feature set (`X`) remains the same across all three models, while the target variable (`y`) changes for each parameter.
#
# For every parameter, the `run_pipeline()` function is executed, which handles data preprocessing, model training, and both in-sample and out-of-sample evaluation. This ensures a consistent workflow and allows for a fair comparison of model performance across different water quality indicators.

# %%
X = wq_data.drop(columns=['Total Alkalinity', 'Electrical Conductance', 'Dissolved Reactive Phosphorus'])

y_TA = wq_data['Total Alkalinity']
y_EC = wq_data['Electrical Conductance']
y_DRP = wq_data['Dissolved Reactive Phosphorus']

model_TA, scaler_TA, results_TA = run_pipeline(X, y_TA, "Total Alkalinity")
model_EC, scaler_EC, results_EC = run_pipeline(X, y_EC, "Electrical Conductance")
model_DRP, scaler_DRP, results_DRP = run_pipeline(X, y_DRP, "Dissolved Reactive Phosphorus")

# %% [markdown]
# ### Model Performance Summary

# %% [markdown]
# After training and evaluating the models for each water quality parameter, the individual performance metrics are combined into a single summary table. This table consolidates the R² and RMSE values for both in-sample and out-of-sample evaluations, enabling an easy comparison of model performance across Total Alkalinity, Electrical Conductance, and Dissolved Reactive Phosphorus.
#
# Such a summary provides a quick overview of how well each model captures the variability in each parameter and highlights any differences in predictive accuracy.

# %%
results_summary = pd.concat([results_TA, results_EC, results_DRP], ignore_index=True)
results_summary

# %% [markdown]
# ## Submission

# %% [markdown]
# Once you are satisfied with your model’s performance, you can proceed to make predictions for unseen data. To do this, use your trained model to estimate the concentrations of the target water quality parameters — Total Alkalinity, Electrical Conductance, and Dissolved Reactive Phosphorus — for a set of test locations provided in the **Submission_template.csv** file.
#
# The predicted results can then be uploaded to the challenge platform for evaluation.

# %%
test_file = pd.read_csv("submission_template.csv")
display(test_file.head(5))

# %%
landsat_val_features = pd.read_csv("landsat_features_validation.csv")
display(landsat_val_features.head(5))

# %%
Terraclimate_val_df = pd.read_csv("terraclimate_features_validation.csv")
display(Terraclimate_val_df.head(5))

# %% [markdown]
# Similarly, participants can use the **Landsat** and **TerraClimate** data extraction demonstration notebooks to produce feature CSVs for their **validation** data. For convenience, we have already computed and saved example validation outputs as `landsat_features_val_V3.csv` and `Terraclimate_val_df_v3.csv`.
#
# Participants should save their own extracted files in the same format and column schema; doing so will allow this benchmark notebook to load the validation features directly and run smoothly.

# %%
#Consolidate all the extracted bands and features in a single dataframe
val_data = pd.DataFrame({
    'Longitude': landsat_val_features['Longitude'].values,
    'Latitude': landsat_val_features['Latitude'].values,
    'Sample Date': landsat_val_features['Sample Date'].values,
    'nir': landsat_val_features['nir'].values,
    'green': landsat_val_features['green'].values,
    'swir16': landsat_val_features['swir16'].values,
    'swir22': landsat_val_features['swir22'].values,
    'NDMI': landsat_val_features['NDMI'].values,
    'MNDWI': landsat_val_features['MNDWI'].values,
    'pet': Terraclimate_val_df['pet'].values,
})

# %%
# Impute the missing values
val_data = val_data.fillna(val_data.median(numeric_only=True))

# %%
# Extracting specific columns (swir22, NDMI, MNDWI, pet) from the validation dataset
submission_val_data=val_data.loc[:,['swir22','NDMI','MNDWI','pet']]
display(submission_val_data.head())

# %%
submission_val_data.shape

# %%
# --- Predicting for Total Alkalinity ---
X_sub_scaled_TA = scaler_TA.transform(submission_val_data)
pred_TA_submission = model_TA.predict(X_sub_scaled_TA)

# --- Predicting for Electrical Conductance ---
X_sub_scaled_EC = scaler_EC.transform(submission_val_data)
pred_EC_submission = model_EC.predict(X_sub_scaled_EC)

# --- Predicting for Dissolved Reactive Phosphorus ---
X_sub_scaled_DRP = scaler_DRP.transform(submission_val_data)
pred_DRP_submission = model_DRP.predict(X_sub_scaled_DRP)

# %%
submission_df = pd.DataFrame({
    'Longitude': test_file['Longitude'].values,
    'Latitude': test_file['Latitude'].values,
    'Sample Date': test_file['Sample Date'].values,
    'Total Alkalinity': pred_TA_submission,
    'Electrical Conductance': pred_EC_submission,
    'Dissolved Reactive Phosphorus': pred_DRP_submission
})

# %%
#Displaying the sample submission dataframe
display(submission_df.head())

# %%
# Save submission locally and to Snowflake
submission_df.to_csv("submission.csv", index=False)
print(f"✅ Submission saved locally with {len(submission_df)} predictions")

# Also save to Snowflake for backup
try:
    # Create a Snowpark DataFrame from the submission
    submission_snowpark_df = session.create_dataframe(submission_df)
    
    # Save to Snowflake table
    submission_snowpark_df.write.mode("overwrite").save_as_table("SUBMISSION_RESULTS")
    print("✅ Submission also saved to Snowflake table: SUBMISSION_RESULTS")
    
    # Show summary stats
    print(f"\n📊 Submission Summary:")
    print(f"- Total Alkalinity range: {submission_df['Total Alkalinity'].min():.2f} - {submission_df['Total Alkalinity'].max():.2f}")
    print(f"- Electrical Conductance range: {submission_df['Electrical Conductance'].min():.2f} - {submission_df['Electrical Conductance'].max():.2f}")
    print(f"- Dissolved Reactive Phosphorus range: {submission_df['Dissolved Reactive Phosphorus'].min():.4f} - {submission_df['Dissolved Reactive Phosphorus'].max():.4f}")
    
except Exception as e:
    print(f"⚠️ Could not save to Snowflake: {e}")
    print("📁 Local file submission.csv is ready for upload")

# %%
# Final submission preparation
import os
from datetime import datetime

print("🎯 BENCHMARK MODEL COMPLETED SUCCESSFULLY!")
print("=" * 60)
print(f"📅 Completion time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"📁 Submission file: {os.getcwd()}/submission.csv")
print(f"📊 Total predictions: {len(submission_df)}")
print("=" * 60)

# Display first few predictions
print("\n🔍 Sample predictions:")
display(submission_df.head(3))

print("\n📤 NEXT STEPS:")
print("1. Download the submission.csv file")
print("2. Upload to the EY AI Challenge platform")
print("3. Check your leaderboard position!")
print(f"\n📍 File location: {os.path.abspath('submission.csv')}")

# Verify file exists and show size
if os.path.exists('submission.csv'):
    file_size = os.path.getsize('submission.csv')
    print(f"✅ File size: {file_size:,} bytes")
else:
    print("❌ Warning: submission.csv not found")

# %% [markdown]
# ### Upload submission file on platform
#
# Upload the `submission.csv` file on the challenge platform to generate your score on the leaderboard.

# %% [markdown]
# ## Conclusion
#
# Now that you have learned a basic approach to model training, it’s time to explore your own techniques and ideas! Feel free to modify any of the functions presented in this notebook to experiment with alternative preprocessing steps, feature engineering strategies, or machine learning algorithms.
#
# We look forward to seeing your enhanced model and the insights you uncover. Best of luck with the challenge!
